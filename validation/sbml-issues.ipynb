# %%
# install packages needed
# !pip install "skm-tools[cytoscape] @ git+ssh://git@github.com/NIB-SI/skm-tools.git"
# !pip install sbmlutils
# Out:
# Collecting skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git
#   Cloning ssh://****@github.com/NIB-SI/skm-tools.git to /tmp/pip-install-r68dgifd/skm-tools_d815aad9fbb34287bbf27b969634ee31
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/NIB-SI/skm-tools.git' /tmp/pip-install-r68dgifd/skm-tools_d815aad9fbb34287bbf27b969634ee31
#   Resolved ssh://****@github.com/NIB-SI/skm-tools.git to commit af75f2cff9e0a23b92323806349707f097641cc6
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkX in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (3.2.1)
# Requirement already satisfied: pandas in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2.3.0)
# Requirement already satisfied: py4cytoscape in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (1.12.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2021.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2.8.2)
# Requirement already satisfied: colour in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (0.1.5)
# Requirement already satisfied: colorbrewer in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (0.3)
# Requirement already satisfied: requests in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2.32.4)
# Requirement already satisfied: igraph in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (0.11.9)
# Requirement already satisfied: chardet in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (5.2.0)
# Requirement already satisfied: decorator in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (5.1.1)
# Requirement already satisfied: backoff in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2.2.1)
# Requirement already satisfied: six>=1.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (1.16.0)
# Requirement already satisfied: texttable>=1.6.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from igraph->py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (1.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->py4cytoscape->skm-tools[cytoscape]@ git+ssh://git@github.com/NIB-SI/skm-tools.git) (3.3)
# Requirement already satisfied: sbmlutils in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (0.8.7)
# Requirement already satisfied: numpy>=1.21.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (1.24.1)
# Requirement already satisfied: markdown-it-py>=2.0.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (3.0.0)
# Requirement already satisfied: fastapi>=0.73.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.115.14)
# Requirement already satisfied: python-multipart>=0.0.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.0.20)
# Requirement already satisfied: py2cytoscape>=0.7.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.7.1)
# Requirement already satisfied: scipy>=1.8 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (1.8.0)
# Requirement already satisfied: uvicorn>=0.14.4 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.35.0)
# Requirement already satisfied: matplotlib>=3.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (3.5.1)
# Requirement already satisfied: python-libsbml>=5.20.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (5.20.5)
# Requirement already satisfied: tabulate>=0.8.9 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.9.0)
# Requirement already satisfied: lxml in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (6.0.0)
# Requirement already satisfied: jinja2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (3.1.6)
# Requirement already satisfied: antimony>=2.13.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (3.0.0)
# Requirement already satisfied: xmltodict in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.14.2)
# Requirement already satisfied: pint>=0.18 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.24.4)
# Requirement already satisfied: beautifulsoup4>=4.10 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (4.10.0)
# Requirement already satisfied: pymetadata>=0.3.11 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (0.4.4)
# Requirement already satisfied: pandas>=2.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (2.3.0)
# Requirement already satisfied: libroadrunner in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (2.2.0)
# Requirement already satisfied: requests in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (2.32.4)
# Requirement already satisfied: pydantic in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (2.11.7)
# Requirement already satisfied: depinfo in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (2.2.0)
# Requirement already satisfied: rich in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (14.0.0)
# Requirement already satisfied: openpyxl>=3.0.9 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (3.1.5)
# Requirement already satisfied: xmlschema>=1.9.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from sbmlutils) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from beautifulsoup4>=4.10->sbmlutils) (2.3.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from fastapi>=0.73.0->sbmlutils) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from fastapi>=0.73.0->sbmlutils) (4.14.0)
# Requirement already satisfied: mdurl~=0.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from markdown-it-py>=2.0.1->sbmlutils) (0.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from matplotlib>=3.5->sbmlutils) (21.3)
# Requirement already satisfied: et-xmlfile in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from openpyxl>=3.0.9->sbmlutils) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas>=2.0->sbmlutils) (2021.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pandas>=2.0->sbmlutils) (2025.2)
# Requirement already satisfied: platformdirs>=2.1.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pint>=0.18->sbmlutils) (2.5.0)
# Requirement already satisfied: flexparser>=0.4 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pint>=0.18->sbmlutils) (0.4)
# Requirement already satisfied: flexcache>=0.3 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pint>=0.18->sbmlutils) (0.3)
# Requirement already satisfied: python-igraph in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py2cytoscape>=0.7.1->sbmlutils) (0.11.9)
# Requirement already satisfied: networkx in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py2cytoscape>=0.7.1->sbmlutils) (3.2.1)
# Requirement already satisfied: pydotplus in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py2cytoscape>=0.7.1->sbmlutils) (2.0.2)
# Requirement already satisfied: pydot in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from py2cytoscape>=0.7.1->sbmlutils) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pydantic->sbmlutils) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pydantic->sbmlutils) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pydantic->sbmlutils) (0.4.1)
# Requirement already satisfied: zeep>=4.2.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pymetadata>=0.3.11->sbmlutils) (4.3.1)
# Requirement already satisfied: pronto>=2.5.6 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pymetadata>=0.3.11->sbmlutils) (2.7.0)
# Requirement already satisfied: fastobo>=0.12.3 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pymetadata>=0.3.11->sbmlutils) (0.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from jinja2->sbmlutils) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->sbmlutils) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->sbmlutils) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->sbmlutils) (3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from requests->sbmlutils) (2.0.12)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from rich->sbmlutils) (2.19.2)
# Requirement already satisfied: h11>=0.8 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from uvicorn>=0.14.4->sbmlutils) (0.16.0)
# Requirement already satisfied: click>=7.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from uvicorn>=0.14.4->sbmlutils) (8.0.3)
# Requirement already satisfied: elementpath<6.0.0,>=5.0.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from xmlschema>=1.9.2->sbmlutils) (5.0.3)
# Requirement already satisfied: chardet~=5.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from pronto>=2.5.6->pymetadata>=0.3.11->sbmlutils) (5.2.0)
# Requirement already satisfied: six>=1.5 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->sbmlutils) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from starlette<0.47.0,>=0.40.0->fastapi>=0.73.0->sbmlutils) (4.9.0)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from zeep>=4.2.1->pymetadata>=0.3.11->sbmlutils) (1.0.0)
# Requirement already satisfied: isodate>=0.5.4 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from zeep>=4.2.1->pymetadata>=0.3.11->sbmlutils) (0.7.2)
# Requirement already satisfied: requests-file>=1.5.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from zeep>=4.2.1->pymetadata>=0.3.11->sbmlutils) (2.1.0)
# Requirement already satisfied: attrs>=17.2.0 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from zeep>=4.2.1->pymetadata>=0.3.11->sbmlutils) (21.4.0)
# Requirement already satisfied: igraph==0.11.9 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from python-igraph->py2cytoscape>=0.7.1->sbmlutils) (0.11.9)
# Requirement already satisfied: texttable>=1.6.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from igraph==0.11.9->python-igraph->py2cytoscape>=0.7.1->sbmlutils) (1.7.0)
# Requirement already satisfied: sniffio>=1.1 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.73.0->sbmlutils) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/cbleker/miniconda3/envs/sys-bio/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.73.0->sbmlutils) (1.3.0)

# %%
from urllib.request import urlretrieve
from pathlib import Path
import pandas as pd

# %%
from sbmlutils.io import read_sbml, validate_sbml
import networkx as nx
import py4cytoscape as p4c

# %%
from skm_tools import cytoscape_utils

# %% [markdown]
# ## Download and load node (and reaction) annotations from SKM

# %%
PSS_NODE_URL = 'https://skm.nib.si/downloads/pss/public/sif-nodes'
pss_node_table_path = Path("./pss-node-annot.tsv")

if not pss_node_table_path.exists():
    print(f"Attempting to download the node annotations to {pss_node_table_path}.", end=" ")
    urlretrieve(PSS_NODE_URL, pss_node_table_path)
    print("Success.")

pss_node_df = pd.read_csv(pss_node_table_path, sep="\t")

# %%
pss_node_df.tail()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   name    node_type short_name functional_cluster_id  \
# 1553   MIZ1[AT2G41660]  PlantCoding       MIZ1               fc00521
# 1554         MIZ1|CPK6      Complex        NaN                   NaN
# 1555        CPK12|GRF8      Complex        NaN                   NaN
# 1556  CPK12[AT5G23580]  PlantCoding      CPK12               fc00523
# 1557   GRF8[AT5G65430]  PlantCoding       GRF8               fc00522
#
#      reaction_id reaction_type reaction_effect additional_information pathway  \
# 1553         NaN           NaN             NaN                    NaN     NaN
# 1554         NaN           NaN             NaN                    NaN     NaN
# 1555         NaN           NaN             NaN                    NaN     NaN
# 1556         NaN           NaN             NaN                    NaN     NaN
# 1557         NaN           NaN             NaN                    NaN     NaN
#
#      all_pathways  ... external_links family function classification  \
# 1553          NaN  ...       gmm:35.2    NaN      NaN            NaN
# 1554          NaN  ...            NaN    NaN      NaN            NaN
# 1555          NaN  ...            NaN    NaN      NaN            NaN
# 1556          NaN  ...       gmm:30.3    NaN      NaN            NaN
# 1557          NaN  ...       gmm:30.7    NaN      NaN            NaN
#
#                                              components ath_homologues  \
# 1553                                                NaN      AT2G41660
# 1554  MIZ1[AT2G41660],CDPK[AT1G35670,AT2G17290,AT3G1...            NaN
# 1555                   GRF8[AT5G65430],CPK12[AT5G23580]            NaN
# 1556                                                NaN      AT5G23580
# 1557                                                NaN      AT5G65430
#
#      nta_homologues osa_homologues stu_homologues sly_homologues
# 1553            NaN            NaN            NaN            NaN
# 1554            NaN            NaN            NaN            NaN
# 1555            NaN            NaN            NaN            NaN
# 1556            NaN            NaN            NaN            NaN
# 1557            NaN            NaN            NaN            NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Parse the SBML to a NetworkX DiGraph

# %%
sbml_path = Path("output.sbml")

# %%
doc = read_sbml(sbml_path)

# %%
model = doc.getModel()

# %%
g = nx.DiGraph()

# %%
for s in model.getListOfSpecies():
    parts = s.getId().split('_')
    label, loc, form = parts[1], parts[2], parts[3]
    g.add_node(s.id, db_name=s.getName(), label=label, sbml_compartment=s.getCompartment(), sbml_type='species', form=form)

# %%
for r in model.getListOfReactions():
    g.add_node(r.id, db_name=r.id, sbml_type='reaction', form='reaction')
    for m in r.getListOfModifiers():
        g.add_edge(m.getSpecies(), r.id, sbml_type="reaction-modifier")
    for s in r.getListOfReactants():
        g.add_edge(s.getSpecies(), r.id, sbml_type="reaction-reactant")
    for p in r.getListOfProducts():
        g.add_edge(r.id, p.getSpecies(), sbml_type="reaction-product")

# %%
g.number_of_nodes(), g.number_of_edges()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (1766, 2071)

# %% [markdown]
# ## Add the node annotations to the graph

# %%
# first map graph nodes (SBML species) to the names in PSS
mapping  = [(n, data["db_name"]) for n, data in g.nodes(data=True)]
mapping_df = pd.DataFrame.from_records(mapping, columns=["id", "db_name"])
mapping_df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   id            db_name
# 0        s_VPg_cyt_p                VPg
# 1     s_LHB1B1_cyt_p  LHB1B1[AT2G34430]
# 2  s_LHB1B1VPg_cyt_c         LHB1B1|VPg
# 3      s_PSB33_cyt_p   PSB33[AT1G71500]
# 4   s_PSB33VPg_cyt_c          PSB33|VPg

# %%
g_node_annots = mapping_df.join(pss_node_df.set_index("name"), on="db_name")
g_node_annots.tail()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            id  db_name node_type short_name functional_cluster_id reaction_id  \
# 1761  rx00960  rx00960  Reaction        NaN                   NaN     rx00960
# 1762  rx00961  rx00961  Reaction        NaN                   NaN     rx00961
# 1763  rx00962  rx00962  Reaction        NaN                   NaN     rx00962
# 1764  rx00963  rx00963  Reaction        NaN                   NaN     rx00963
# 1765  rx00964  rx00964  Reaction        NaN                   NaN     rx00964
#
#                 reaction_type reaction_effect additional_information pathway  \
# 1761  binding/oligomerisation      activation                    NaN     NaN
# 1762            translocation      activation                    NaN     NaN
# 1763       protein activation      activation                    NaN     NaN
# 1764       protein activation      activation                    NaN     NaN
# 1765       protein activation      activation                    NaN     NaN
#
#       ...                  external_links family function classification  \
# 1761  ...  doi:10.1016/j.molp.2023.04.002    NaN      NaN            NaN
# 1762  ...  doi:10.1016/j.molp.2023.04.002    NaN      NaN            NaN
# 1763  ...  doi:10.1016/j.molp.2023.04.002    NaN      NaN            NaN
# 1764  ...  doi:10.1016/j.molp.2023.04.002    NaN      NaN            NaN
# 1765  ...  doi:10.1016/j.molp.2023.04.002    NaN      NaN            NaN
#
#      components ath_homologues nta_homologues osa_homologues stu_homologues  \
# 1761        NaN            NaN            NaN            NaN            NaN
# 1762        NaN            NaN            NaN            NaN            NaN
# 1763        NaN            NaN            NaN            NaN            NaN
# 1764        NaN            NaN            NaN            NaN            NaN
# 1765        NaN            NaN            NaN            NaN            NaN
#
#      sly_homologues
# 1761            NaN
# 1762            NaN
# 1763            NaN
# 1764            NaN
# 1765            NaN
#
# [5 rows x 24 columns]

# %%
g_node_annots.set_index("id", inplace=True, drop=True)
nx.set_node_attributes(g, g_node_annots.to_dict('index'))

# %% [markdown]
# ## View in Cytoscape

# %%
suid = p4c.create_network_from_networkx(g, title=str(sbml_path))
p4c.set_visual_style("sbml", suid) # this style is in the attached cytoscape session
# Out:
# Applying default style...
# Applying preferred layout
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'message': 'Visual Style applied.'}

# %% [markdown]
# ## Look for seperation of nodes based on "form" and/or "location"

# %%
# where the same node name appears more than once
multiple_occurances = [n 
                  for n, df 
                  in g_node_annots.groupby("db_name") 
                  if df.shape[0] > 1
]
print(len(multiple_occurances))
# Out:
# 174

# %%
def extract_neighbourhood(nodes, graph):
    neighbours = set()
    for n in nodes:
        neighbours.update(graph.to_undirected(as_view=True).neighbors(n))
    return list(neighbours)

# %%
problematic_nodes = []
for target in multiple_occurances:
    sbml_species = [
        node
        for node, data
        in g.nodes(data=True)
        if data.get("db_name") == target
    ]
    
    reactions = extract_neighbourhood(sbml_species, g)
    subgraph_nodes = reactions + extract_neighbourhood(reactions, g)
    subgraph = nx.induced_subgraph(g, subgraph_nodes)
    is_species_connected = nx.is_weakly_connected(subgraph)

    if not is_species_connected:
        print(target, sbml_species, reactions)
        problematic_nodes.append(target)
# Out:
# AAO[AT1G04580,AT2G27150,AT5G20960] ['s_AAO_chl_pa', 's_AAO_cyt_pa'] ['rx00077', 'rx00552', 'rx00538']
# ABA ['s_ABA_cyt_m', 's_ABA_ap_m'] ['rx00552', 'rx00749', 'rx00751', 'rx00474']
# ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] ['s_ACO_cyt_pa', 's_ACO_er_pa', 's_ACO_cyt_p'] ['rx00193', 'rx00003', 'rx00855']
# ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] ['s_ACS_cyt_pa', 's_ACS_cyt_p', 's_ACS_er_pa'] ['rx00716', 'rx00853', 'rx00140', 'rx00002', 'rx00248']
# AGO1[AT1G48410] ['s_AGO1_cyt_pa', 's_AGO1_nuc_nc', 's_AGO1_cyt_mr'] ['rx00200', 'rx00199', 'rx00653', 'rx00589', 'rx00593']
# AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000] ['s_AREBABF_cyt_p', 's_AREBABF_cyt_pa', 's_AREBABF_nuc_p'] ['rx00849', 'rx00576', 'rx00569', 'rx00607', 'rx00571', 'rx00848', 'rx00830', 'rx00605', 'rx00831', 'rx00610', 'rx00833', 'rx00832', 'rx00850']
# ATAF1[AT1G01720] ['s_ATAF1_cyt_pa', 's_ATAF1_nuc_p'] ['rx00709', 'rx00710']
# BA ['s_BA_chl_m', 's_BA_per_m', 's_BA_cyt_m'] ['rx00538', 'rx00078', 'rx00077', 'rx00536', 'rx00537']
# BA-CoA ['s_BACoA_cyt_m', 's_BACoA_per_m'] ['rx00536', 'rx00535']
# BGLU18[AT1G52400] ['s_BGLU18_er_pa', 's_BGLU18_cyt_p', 's_BGLU18_cyt_pa'] ['rx00750', 'rx00749']
# BN2[SOTUB04G034100.1.1] ['s_BN2_cyt_p', 's_BN2_cyt_pa'] ['rx00904', 'rx00905']
# BRI1[AT4G39400] ['s_BRI1_cyt_p', 's_BRI1_cyt_pa'] ['rx00529', 'rx00744']
# CA ['s_CA_per_m', 's_CA_chl_m', 's_CA_cyt_m'] ['rx00076', 'rx00532', 'rx00543', 'rx00533', 'rx00077', 'rx00531']
# CAMTA3[AT2G22300,SOTUB04G020530.1.1] ['s_CAMTA3_nuc_pa', 's_CAMTA3_cyt_p', 's_CAMTA3_cyt_pa'] ['rx00904', 'rx00148', 'rx00184', 'rx00150', 'rx00186', 'rx00447']
# CBL2|CIPK26 ['s_CBL2CIPK26_cyt_c', 's_CBL2CIPK26_cyt_ca'] ['rx00934', 'rx00928', 'rx00889', 'rx00937']
# CBL2|CIPK3 ['s_CBL2CIPK3_cyt_c', 's_CBL2CIPK3_cyt_ca'] ['rx00926', 'rx00932', 'rx00886']
# CBL2|CIPK9 ['s_CBL2CIPK9_cyt_c', 's_CBL2CIPK9_cyt_ca'] ['rx00933', 'rx00927', 'rx00887']
# CBL3|CIPK26 ['s_CBL3CIPK26_cyt_c', 's_CBL3CIPK26_cyt_ca'] ['rx00893', 'rx00931']
# CBL3|CIPK3 ['s_CBL3CIPK3_cyt_c', 's_CBL3CIPK3_cyt_ca'] ['rx00935', 'rx00890', 'rx00929']
# CBL3|CIPK9 ['s_CBL3CIPK9_cyt_c', 's_CBL3CIPK9_cyt_ca'] ['rx00936', 'rx00891', 'rx00930']
# CBP60G[AT5G26920] ['s_CBP60G_nuc_p', 's_CBP60G_nuc_pa', 's_CBP60G_cyt_pa'] ['rx00770', 'rx00183', 'rx00781', 'rx00761', 'rx00768', 'rx00804', 'rx00769', 'rx00820', 'rx00824', 'rx00802', 'rx00780', 'rx00823', 'rx00817', 'rx00798', 'rx00763', 'rx00801', 'rx00819', 'rx00805', 'rx00190', 'rx00773', 'rx00774', 'rx00800', 'rx00825', 'rx00818', 'rx00822', 'rx00779', 'rx00799', 'rx00759', 'rx00803', 'rx00821']
# CDF1[PGSC0003DMG400018408,SOLTU.DM.05G005140.1] ['s_CDF1_nuc_pa', 's_CDF1_cyt_pa'] ['rx00407', 'rx00871', 'rx00868', 'rx00867']
# CDK[AT5G63610] ['s_CDK_nuc_p', 's_CDK_nuc_pa'] ['rx00726', 'rx00502', 'rx00504', 'rx00501']
# CI ['s_CI_cyt_p', 's_CI_cyt_pa'] ['rx00200', 'rx00214', 'rx00636', 'rx00585']
# CML[AT1G66410,AT3G01830,AT4G20780,SOTUB02G034770.1.1] ['s_CML_cyt_pa', 's_CML_cyt_p'] ['rx00219', 'rx00173']
# CO2-deficiency ['s_CO2deficiency_chl_pra', 's_CO2deficiency_chl_pr', 's_CO2deficiency_cyt_pra'] ['rx00134', 'rx00600', 'rx00912', 'rx00614']
# COI1[AT2G39940] ['s_COI1_nuc_pa', 's_COI1_cyt_p', 's_COI1_cyt_pa'] ['rx00232', 'rx00043', 'rx00730', 'rx00925', 'rx00196']
# CP ['s_CP_cyt_p', 's_CP_cyt_pa'] ['rx00584', 'rx00641', 'rx00201']
# CTS[AT4G39850] ['s_CTS_chl_pa', 's_CTS_per_pa'] ['rx00031', 'rx00531']
# DELLA[AT1G14920,AT1G66350,AT2G01570,AT3G03450,AT5G17490] ['s_DELLA_nuc_p', 's_DELLA_nuc_pa', 's_DELLA_cyt_p'] ['rx00292', 'rx00163', 'rx00162', 'rx00844', 'rx00838', 'rx00842', 'rx00159', 'rx00703', 'rx00505']
# EDS5[AT4G39030] ['s_EDS5_chl_pa', 's_EDS5_cyt_p'] ['rx00517', 'rx00761', 'rx00760']
# EIN2[AT5G03280] ['s_EIN2_er_p', 's_EIN2_er_pa', 's_EIN2_nuc_pa', 's_EIN2_cyt_pa'] ['rx00430', 'rx00010', 'rx00009', 'rx00525', 'rx00210', 'rx00015']
# EIN3(like)[AT2G27050,AT3G20770] ['s_EIN3like_nuc_pa', 's_EIN3like_nuc_p', 's_EIN3like_cyt_p'] ['rx00158', 'rx00018', 'rx00711', 'rx00240', 'rx00013', 'rx00019', 'rx00017', 'rx00235', 'rx00186', 'rx00015']
# EIN3|NPR1 ['s_EIN3NPR1_nuc_ca', 's_EIN3NPR1_cyt_c'] ['rx00712', 'rx00711']
# ERF11[AT1G28370] ['s_ERF11_nuc_pa', 's_ERF11_cyt_p', 's_ERF11_cyt_pa'] ['rx00716', 'rx00715', 'rx00411']
# ERF1[AT3G23240,AT4G17500,SOTUB12G018730.1.1] ['s_ERF1_cyt_pa', 's_ERF1_nuc_pa', 's_ERF1_cyt_p'] ['rx00436', 'rx00158', 'rx00206', 'rx00151']
# GA20ox[AT1G44090,AT1G60980,AT4G25420,AT5G07200,AT5G51810,SOTUB01G031210.1.1,SOTUB03G007160.1.1,SOTUB09G017710.1.1,SOTUB10G011620.1.1,SOTUB11G029030.1.1] ['s_GA20ox_cyt_pa', 's_GA20ox_cyt_p'] ['rx00268', 'rx00788', 'rx00277', 'rx00269', 'rx00276']
# GI[AT1G22770] ['s_GI_nuc_p', 's_GI_cyt_p'] ['rx00703', 'rx00704']
# HC-Pro ['s_HCPro_cyt_p', 's_HCPro_cyt_pa'] ['rx00581', 'rx00198', 'rx00205', 'rx00219', 'rx00211', 'rx00215', 'rx00199', 'rx00580', 'rx00218', 'rx00204', 'rx00207', 'rx00522', 'rx00582', 'rx00197', 'rx00588', 'rx00220', 'rx00212', 'rx00213']
# HSP70|HSP90|SGT1 ['s_HSP70HSP90SGT1_cyt_c', 's_HSP70HSP90SGT1_cyt_ca'] ['rx00729', 'rx00730']
# IAA ['s_IAA_cyt_m', 's_IAA_chl_m'] ['rx00754', 'rx00418', 'rx00462', 'rx00458', 'rx00417', 'rx00414', 'rx00434', 'rx00442', 'rx00448', 'rx00457']
# IPT1,3,4,5,6,7,8[AT1G25410,AT1G68460,AT3G19160,AT3G23630,AT3G63110,AT4G24650,AT5G19040] ['s_IPT1345678_cyt_pa', 's_IPT1345678_cyt_p'] ['rx00708', 'rx00322']
# ISPH[AT4G34350] ['s_ISPH_cyt_pa', 's_ISPH_cyt_p'] ['rx00901', 'rx00321']
# JAM[AT1G01260,AT2G46510,AT4G16430] ['s_JAM_nuc_pa', 's_JAM_cyt_pa', 's_JAM_cyt_p'] ['rx00874', 'rx00206', 'rx00872', 'rx00877', 'rx00873', 'rx00880', 'rx00879']
# JAZ[AT1G17380,AT1G19180,AT1G30135,AT1G48500,AT1G70700,AT1G72450,AT1G74950,AT2G34600,AT3G17860,AT3G43440,AT5G13220,AT5G20900] ['s_JAZ_nuc_pa', 's_JAZ_cyt_pa', 's_JAZ_cyt_p'] ['rx00874', 'rx00018', 'rx00044', 'rx00872', 'rx00159', 'rx00873', 'rx00062', 'rx00128', 'rx00046', 'rx00233', 'rx00047']
# L-arogenate ['s_Larogenate_cyt_m', 's_Larogenate_chl_m'] ['rx00542', 'rx00540', 'rx00541']
# MIR390[AT2G38325,AT5G58465] ['s_MIR390_cyt_nc', 's_MIR390_cyt_mi'] ['rx00626', 'rx00111']
# MYC2[AT1G32640] ['s_MYC2_nuc_pa', 's_MYC2_nuc_p', 's_MYC2_cyt_pa'] ['rx00432', 'rx00253', 'rx00698', 'rx00250', 'rx00046', 'rx00049', 'rx00163', 'rx00051', 'rx00510', 'rx00047', 'rx00459', 'rx00050', 'rx00251', 'rx00697', 'rx00877', 'rx00507', 'rx00509', 'rx00052', 'rx00162', 'rx00028', 'rx00508', 'rx00410', 'rx00252']
# NAC019[AT1G52890] ['s_NAC019_nuc_pa', 's_NAC019_cyt_p'] ['rx00439', 'rx00251', 'rx00254', 'rx00257', 'rx00854', 'rx00850', 'rx00858']
# NAC055[AT3G15500] ['s_NAC055_nuc_pa', 's_NAC055_cyt_p'] ['rx00860', 'rx00255', 'rx00607', 'rx00258', 'rx00852', 'rx00857', 'rx00252', 'rx00606']
# NAC072[AT4G27410] ['s_NAC072_nuc_pa', 's_NAC072_cyt_p'] ['rx00849', 'rx00256', 'rx00859', 'rx00848', 'rx00253', 'rx00259', 'rx00863']
# NAC92[AT5G39610] ['s_NAC92_nuc_p', 's_NAC92_cyt_p', 's_NAC92_cyt_pa'] ['rx00734', 'rx00712', 'rx00733']
# NCED[AT1G30100,AT1G78390,AT3G14440,AT3G24220,AT4G18350,AT4G19170] ['s_NCED_cyt_pa', 's_NCED_cyt_p'] ['rx00709', 'rx00748', 'rx00554']
# ORA59[AT1G06160] ['s_ORA59_nuc_pa', 's_ORA59_nuc_g', 's_ORA59_cyt_pa'] ['rx00154', 'rx00155', 'rx00859', 'rx00452', 'rx00858', 'rx00250', 'rx00857', 'rx00436', 'rx00153', 'rx00450', 'rx00453', 'rx00443', 'rx00685', 'rx00151', 'rx00454', 'rx00441', 'rx00157']
# P3 ['s_P3_cyt_p', 's_P3_cyt_pa'] ['rx00583', 'rx00221']
# PAD4[AT3G52430] ['s_PAD4_nuc_pa', 's_PAD4_cyt_p'] ['rx00772', 'rx00087', 'rx00774', 'rx00161']
# PBS3[AT5G13320] ['s_PBS3_cyt_pa', 's_PBS3_cyt_p'] ['rx00767', 'rx00770', 'rx00514']
# PHYB[AT2G18790] ['s_PHYB_cyt_pa', 's_PHYB_cyt_p', 's_PHYB_nuc_pa'] ['rx00826', 'rx00840', 'rx00837', 'rx00917']
# PIF3,4[AT1G09530,SOTUB07G016670.1.1] ['s_PIF34_cyt_pa', 's_PIF34_nuc_pa', 's_PIF34_nuc_p', 's_PIF34_cyt_p'] ['rx00917', 'rx00840', 'rx00505', 'rx00618', 'rx00839']
# PR5[AT1G75040] ['s_PR5_cyt_p', 's_PR5_cyt_pa'] ['rx00103', 'rx00673']
# Phe ['s_Phe_chl_m', 's_Phe_cyt_m'] ['rx00541', 'rx00460', 'rx00076']
# Photosynthesis ['s_Photosynthesis_chl_pra', 's_Photosynthesis_cyt_pra', 's_Photosynthesis_cyt_pr'] ['rx00912', 'rx00910']
# Prep ['s_Prep_chl_m', 's_Prep_cyt_m'] ['rx00540', 'rx00073']
# RBC[AT1G67090,AT5G38430,ATCG00490] ['s_RBC_cyt_pa', 's_RBC_cyt_p'] ['rx00232', 'rx00233', 'rx00677', 'rx00221']
# RBOH[AT1G09090,AT1G19230,AT1G64060,AT3G45810,AT4G11230,AT4G25090,AT5G07390,AT5G47910,AT5G51060,AT5G60010,SOTUB06G025550.1.1,SOTUB06G025580.1.1,SOTUB08G028720.1.1] ['s_RBOH_ap_pa', 's_RBOH_ap_p', 's_RBOH_cyt_p'] ['rx00239', 'rx00427', 'rx00449', 'rx00174', 'rx00132', 'rx00702', 'rx00451']
# RISC - vsiRNA ['s_RISCvsiRNA_cyt_pr', 's_RISCvsiRNA_cyt_ca'] ['rx00115', 'rx00593']
# ROS ['s_ROS_chl_m', 's_ROS_mit_m', 's_ROS_x_m', 's_ROS_cyt_m'] ['rx00164', 'rx00260', 'rx00014', 'rx00132', 'rx00131', 'rx00134', 'rx00262', 'rx00149', 'rx00095', 'rx00133', 'rx00261']
# SA ['s_SA_cyt_m', 's_SA_chl_m'] ['rx00114', 'rx00516', 'rx00234', 'rx00086', 'rx00422', 'rx00056', 'rx00078', 'rx00311', 'rx00083', 'rx00423', 'rx00500', 'rx00419', 'rx00501', 'rx00515']
# SAGs[AT5G14930,AT5G45890] ['s_SAGs_nuc_p', 's_SAGs_nuc_pa'] ['rx00127', 'rx00054']
# SAHH[AT3G23810] ['s_SAHH_er_pa', 's_SAHH_er_p', 's_SAHH_cyt_pa'] ['rx00594', 'rx00198']
# SAMS[AT1G02500,AT2G36880,AT3G17390,AT4G01850] ['s_SAMS_er_pa', 's_SAMS_er_p', 's_SAMS_cyt_pa'] ['rx00001', 'rx00197']
# SAMe ['s_SAMe_cyt_m', 's_SAMe_cyt_mr'] ['rx00001', 'rx00002', 'rx00592']
# SARD1[AT1G73805] ['s_SARD1_nuc_pa', 's_SARD1_cyt_pa'] ['rx00767', 'rx00811', 'rx00815', 'rx00808', 'rx00810', 'rx00816', 'rx00428', 'rx00776', 'rx00764', 'rx00766', 'rx00807', 'rx00812', 'rx00760', 'rx00794', 'rx00784', 'rx00813', 'rx00758', 'rx00797', 'rx00791', 'rx00806', 'rx00771', 'rx00792', 'rx00437', 'rx00796', 'rx00795', 'rx00762', 'rx00778', 'rx00772', 'rx00793', 'rx00809', 'rx00814', 'rx00777']
# SGT1[AT4G11260,AT4G23570] ['s_SGT1_cyt_p', 's_SGT1_cyt_pa'] ['rx00053', 'rx00729', 'rx00731']
# SOD[AT1G08830,AT1G12520,AT2G28190,AT3G56350,AT5G18100] ['s_SOD_mit_pa', 's_SOD_cyt_p'] ['rx00746', 'rx00131']
# TGA2,5,6[AT3G12250,AT5G06950,AT5G06960] ['s_TGA256_nuc_pa', 's_TGA256_cyt_pa'] ['rx00209', 'rx00156', 'rx00942', 'rx00151', 'rx00504', 'rx00099']
# TIR1[AT3G62980] ['s_TIR1_nuc_p', 's_TIR1_nuc_pa', 's_TIR1_cyt_p', 's_TIR1_cyt_pa'] ['rx00463', 'rx00462', 'rx00731']
# VPg ['s_VPg_cyt_p', 's_VPg_cyt_pa'] ['rx00670', 'rx00586', 'rx00623', 'rx00629', 'rx00682', 'rx00663', 'rx00634', 'rx00662', 'rx00681', 'rx00692', 'rx00635', 'rx00640', 'rx00671', 'rx00665', 'rx00673', 'rx00689', 'rx00668', 'rx00691', 'rx00667', 'rx00620', 'rx00622', 'rx00628', 'rx00621', 'rx00627', 'rx00226', 'rx00227', 'rx00674', 'rx00672', 'rx00683', 'rx00688', 'rx00675', 'rx00521', 'rx00669', 'rx00633', 'rx00638', 'rx00687', 'rx00639', 'rx00679', 'rx00641', 'rx00676', 'rx00632', 'rx00630', 'rx00680', 'rx00636', 'rx00677', 'rx00619', 'rx00664', 'rx00666', 'rx00678', 'rx00690', 'rx00520', 'rx00686', 'rx00631']
# WRKY6,18[AT4G31800] ['s_WRKY618_nuc_pa', 's_WRKY618_cyt_p'] ['rx00500', 'rx00502', 'rx00309']
# WRKY70[AT3G56400] ['s_WRKY70_cyt_pa', 's_WRKY70_cyt_p'] ['rx00098', 'rx00759', 'rx00758', 'rx00244']
# me-vsiRNA ['s_mevsiRNA_cyt_mr', 's_mevsiRNA_cyt_pa'] ['rx00593', 'rx00592', 'rx00581']
# miR168[AT4G19395,MIR168] ['s_miR168_cyt_pa', 's_miR168_nuc_nc', 's_miR168_cyt_mi'] ['rx00588', 'rx00653', 'rx00589', 'rx00905']
# miR398b[AT5G14545] ['s_miR398b_cyt_p', 's_miR398b_cyt_mi'] ['rx00745', 'rx00746']
# phospholipids ['s_phospholipids_chl_m', 's_phospholipids_cyt_m'] ['rx00693', 'rx00624']
# potyvirus ['s_potyvirus_cyt_pa', 's_potyvirus_cyt_f'] ['rx00115', 'rx00586', 'rx00585', 'rx00583', 'rx00107', 'rx00582', 'rx00590', 'rx00080', 'rx00584']

# %%
print(len(problematic_nodes))
# Out:
# 85

# %%
# example to extract a "problematic" node in cytpscape
s_network_suid = cytoscape_utils.subnetwork_node_induced(
    subgraph_nodes,
    suid,
    name=target,
)
p4c.layout_network("cose", s_network_suid)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {}

# %% [markdown]
# ## Extracting model input and output nodes

# %%
outputs = [node for node in g.nodes if g.out_degree(node) == 0 and node.startswith ('s_')]
outputs
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     's_LHB1B1VPg_cyt_c',
#     's_PSB33VPg_cyt_c',
#     's_CRTHCPro_cyt_ca',
#     's_EDF2HCPro_cyt_ca',
#     's_CMLHCPro_cyt_ca',
#     's_EDS1MPK3PAD4_cyt_ca',
#     's_SERPIN1VPg_cyt_c',
#     's_CLPP1VPg_cyt_c',
#     's_FQR1VPg_cyt_c',
#     's_PR3VPg_cyt_c',
#     's_HCProTDX_cyt_ca',
#     's_P3RBC_cyt_ca',
#     's_OBE1VPg_cyt_ca',
#     's_RH8VPg_cyt_ca',
#     's_RPS12CVPg_cyt_c',
#     's_MTI2011VPg_cyt_c',
#     's_CRTETR_cyt_ca',
#     's_CRTCa2_cyt_ca',
#     's_SAMS_er_p',
#     's_SAHH_er_p',
#     's_HSP90RAR1SGT1_cyt_ca',
#     's_PR5VPg_cyt_c',
#     's_AGO15710HCPro_cyt_ca',
#     's_AGO15710CI_cyt_ca',
#     's_CPCPIP_cyt_ca',
#     's_ATG13A_cyt_p',
#     's_DXPS2HCPro_cyt_ca',
#     's_ATPBHCPro_cyt_ca',
#     's_NDR1RIN4_cyt_ca',
#     's_HCProMIND1_cyt_ca',
#     's_HCProPAA2_cyt_ca',
#     's_HCProPBB2_cyt_ca',
#     's_RANGAPRx_cyt_ca',
#     's_GPAphid2RANGAP_cyt_ca',
#     's_HCProPBE1_cyt_ca',
#     's_OBE1WRKY17_cyt_ca',
#     's_OBE1WRKY11_cyt_ca',
#     's_COOBE1_cyt_ca',
#     's_COI1RBC_cyt_ca',
#     's_JAZRBC_cyt_ca',
#     's_GAPC2VPg_cyt_c',
#     's_AT3G17020VPg_cyt_c',
#     's_HEN1_cyt_p',
#     's_NpyruvoylLGlu_cyt_m',
#     's_MKS1WRKY33_cyt_ca',
#     's_CIPSAK_cyt_ca',
#     's_ESPWRKY53_cyt_ca',
#     's_WRKY30WRKY53_cyt_ca',
#     's_JAZWRKY57_cyt_ca',
#     's_AUXIAAWRKY57_cyt_ca',
#     's_DELLAJAZ_nuc_ca',
#     's_DELLAMYC_nuc_ca',
#     's_CATLSD1_cyt_ca',
#     's_cZglucosides_cyt_m',
#     's_TIP12VPg_cyt_c',
#     's_NIMINNPR1_nuc_ca',
#     's_MDA_chl_m',
#     's_Rgenepotyvirus_cyt_ca',
#     's_OBE2VPg_cyt_c',
#     's_Prep_chl_m',
#     's_SA_chl_m',
#     's_MYCPYL_nuc_c',
#     's_ATG1A_cyt_p',
#     's_SAG_vac_m',
#     's_ROS_mit_m',
#     's_ROS_x_m',
#     's_GA8_cyt_m',
#     's_GA34_cyt_m',
#     's_GAmethylester_cyt_m',
#     's_Growth_cyt_pra',
#     's_OPDA_cyt_m',
#     's_DZglucosides_cyt_m',
#     's_EIN3likeJAZ_nuc_ca',
#     's_CIVPg_cyt_c',
#     's_tZglucoside_cyt_m',
#     's_iPglucosides_cyt_m',
#     's_AGO1_nuc_nc',
#     's_ACS_er_pa',
#     's_ERF5_cyt_pa',
#     's_ERF104_cyt_pa',
#     's_ERF105_cyt_pa',
#     's_WAK1_cyt_pa',
#     's_Tyr_cyt_m',
#     's_WDbHLHMYB_nuc_c',
#     's_PDF12_cyt_pa',
#     's_CLH_cyt_pa',
#     's_JR1_cyt_pa',
#     's_PR13_cyt_pa',
#     's_VSP_cyt_pa',
#     's_Anthocyaninaccumulation_cyt_pra',
#     's_WRKY70_cyt_pa',
#     's_PR2_cyt_pa',
#     's_PR5_cyt_pa',
#     's_SEN4_cyt_pa',
#     's_SAGs_nuc_pa',
#     's_MYB113_cyt_pa',
#     's_ERF096_cyt_pa',
#     's_ERF1_cyt_pa',
#     's_ACO_er_pa',
#     's_WRKY46_nuc_pa',
#     's_NAC032_cyt_pa',
#     's_Ade_cyt_m',
#     's_BACoA_cyt_m',
#     's_TUA2VPg_cyt_c',
#     's_HSP_cyt_pa',
#     's_REM12VPg_cyt_c',
#     's_SP6A_nuc_pa',
#     's_EIF4EVPg_cyt_c',
#     's_BT4_cyt_pa',
#     's_EIF4EHCPro_cyt_c',
#     's_EDS1_cyt_p',
#     's_SAAsp_cyt_m',
#     's_Thiohydroximate_cyt_m',
#     's_5phosphomevalonate_cyt_m',
#     's_MYC2_nuc_p',
#     's_IAOxNoxide_cyt_m',
#     's_ERF1_cyt_p',
#     's_SARD1TCP8_nuc_c',
#     's_TCP8WRKY28_nuc_c',
#     's_NAC019TCP8_nuc_c',
#     's_FKBP65_cyt_pa',
#     's_UTR1_cyt_pa',
#     's_BGLU30_cyt_p',
#     's_CYP81F4_cyt_pa',
#     's_DR4_cyt_pa',
#     's_ERF016_cyt_pa',
#     's_IAAGlu_chl_m',
#     's_IAAAsp_cyt_m',
#     's_PAA_cyt_m',
#     's_DOPAL_cyt_m',
#     's_GH37_nuc_p',
#     's_HSP181CI_cyt_pa',
#     's_SAUR41_cyt_pa',
#     's_PP2C_cyt_p',
#     's_GBF4_nuc_pa',
#     's_GER3VPg_cyt_c',
#     's_HSP265MII_cyt_pa',
#     's_RD29_cyt_pa',
#     's_XTH_nuc_p',
#     's_CYCD33_nuc_p',
#     's_NPR1WRKY18_cyt_c',
#     's_CDKNPR1_cyt_c',
#     's_CDKWRKY618_cyt_c',
#     's_CDKTGA256_cyt_c',
#     's_PIF34_nuc_p',
#     's_BA_cyt_m',
#     's_BIK1PEPR1PEP1_cyt_c',
#     's_P3_cyt_pa',
#     's_CP_cyt_pa',
#     's_CI_cyt_pa',
#     's_VPg_cyt_pa',
#     's_miR168_nuc_nc',
#     's_PABP2VPg_cyt_c',
#     's_mevsiRNA_cyt_mr',
#     's_RISCvsiRNA_cyt_ca',
#     's_PABP4VPg_cyt_c',
#     's_HCProvsiRNA_cyt_mr',
#     's_ETETR_cyt_ca',
#     's_PABP8VPg_cyt_c',
#     's_6K2VPg_cyt_c',
#     's_RISCmiR390_cyt_c',
#     's_PORBVPg_cyt_c',
#     's_PORAVPg_cyt_c',
#     's_FBA8VPg_cyt_c',
#     's_GSTF9VPg_cyt_c',
#     's_HUP54VPg_cyt_c',
#     's_VDAC2VPg_cyt_c',
#     's_PSBRVPg_cyt_c',
#     's_LOX2VPg_cyt_c',
#     's_P1VPg_cyt_c',
#     's_JAZMYC_nuc_ca',
#     's_MSL_cyt_pa',
#     's_NIaProVPg_cyt_c',
#     's_NIbVPg_cyt_c',
#     's_CPVPg_cyt_c',
#     's_BAS1VPg_cyt_c',
#     's_RBCLVPg_cyt_c',
#     's_PSBP1VPg_cyt_c',
#     's_RCAVPg_cyt_c',
#     's_MED37EVPg_cyt_c',
#     's_IPP2VPg_cyt_c',
#     's_ABCF1VPg_cyt_c',
#     's_CLPR3VPg_cyt_c',
#     's_ACT_nuc_p',
#     's_PSBBVPg_cyt_c',
#     's_BCCP1VPg_cyt_c',
#     's_GRF6VPg_cyt_c',
#     's_CAC2VPg_cyt_c',
#     's_GSTF2VPg_cyt_c',
#     's_MPPBETAVPg_cyt_c',
#     's_ATPC1VPg_cyt_c',
#     's_MYC3NPR1_cyt_p',
#     's_MYC4NPR1_cyt_p',
#     's_CPI8_vac_pa',
#     's_MC_cyt_pa',
#     's_ADH1_cyt_p',
#     's_RBOH_cyt_p',
#     's_GAIGI_nuc_c',
#     's_GIPIF4_cyt_c',
#     's_AGL16_cyt_p',
#     's_Prolineaccumulation_cyt_pr',
#     's_IPT1345678_cyt_p',
#     's_NCED_cyt_p',
#     's_ATAF1_nuc_p',
#     's_PTP1a_cyt_pa',
#     's_NAC92_nuc_p',
#     's_EIN3NPR1_cyt_c',
#     's_ERF11_cyt_p',
#     's_CDKRAP26_nuc_c',
#     's_RAP26SNRK2_cyt_c',
#     's_InsP8_cyt_m',
#     's_HSP70HSP90SGT1_cyt_c',
#     's_COI1_cyt_pa',
#     's_TIR1_cyt_pa',
#     's_ENDO1_cyt_p',
#     's_CML12PID_cyt_c',
#     's_PBP1PID_cyt_c',
#     's_CMI1ICR1_cyt_c',
#     's_miR398b_cyt_p',
#     's_SOD_cyt_p',
#     's_ABA_ap_m',
#     's_BGLU18_cyt_pa',
#     's_DPA_cyt_m',
#     's_oxIAA_cyt_m',
#     's_UGT79B2_cyt_p',
#     's_UGT79B3_cyt_p',
#     's_12OHJA_cyt_m',
#     's_WRKY70_cyt_p',
#     's_EDS5_cyt_p',
#     's_FMO1_cyt_p',
#     's_ROP9SlRBOHB_cyt_c',
#     's_ALD1_cyt_p',
#     's_PBS3_cyt_p',
#     's_PAD4_cyt_p',
#     's_FKBP42HSP90_cyt_c',
#     's_ADR1_cyt_p',
#     's_ADR1L1_cyt_p',
#     's_ADR1L2_cyt_p',
#     's_FKBP42CAM_cyt_c',
#     's_MPK7_cyt_pa',
#     's_ELF3_cyt_p',
#     's_GA20ox_cyt_p',
#     's_CBL1CIPK1_cyt_c',
#     's_CBL9CIPK1_cyt_c',
#     's_SERK4_cyt_p',
#     's_GB1_cyt_p',
#     's_PUB13_cyt_p',
#     's_WRKY40_cyt_p',
#     's_WRKY60_cyt_p',
#     's_NUDT6_cyt_p',
#     's_NUDT7_cyt_p',
#     's_MLO2_cyt_p',
#     's_BON1_cyt_p',
#     's_BAP1_cyt_p',
#     's_BAP2_cyt_p',
#     's_FKBP62HSP901_cyt_c',
#     's_CBL1CIPK23_cyt_c',
#     's_CBL9CIPK23_cyt_c',
#     's_ABF1IDD14_nuc_c',
#     's_ABF2IDD14_nuc_c',
#     's_ABF3IDD14_nucl_c',
#     's_ABF4IDD14_nuc_c',
#     's_HSFA1dPIF4_cyt_c',
#     's_ABI4RGL2_cyt_c',
#     's_PIF34_cyt_p',
#     's_ABI5HY5_cyt_c',
#     's_NAC072_cyt_p',
#     's_NAC019_cyt_p',
#     's_NAC055_cyt_p',
#     's_ACO_cyt_p',
#     's_NPF31_cyt_p',
#     's_NR_cyt_p',
#     's_Ca2_vac_m',
#     's_ORE1SO2_cyt_p',
#     's_JAZ_cyt_p',
#     's_CBL2CIPK3Ca2_cyt_c',
#     's_CBL2CIPK9Ca2_cyt_c',
#     's_JAM_cyt_p',
#     's_CBL2CIPK26Ca2_cyt_c',
#     's_CBL3CIPK3Ca2_cyt_c',
#     's_CBL3CIPK9Ca2_cyt_c',
#     's_CBL3CIPK26Ca2_cyt_c',
#     's_PR1cholesterol_cyt_c',
#     's_CBL2CIPK3_cyt_c',
#     's_CBL2CIPK9_cyt_c',
#     's_CBL2CIPK23_cyt_c',
#     's_CBL2CIPK26_cyt_c',
#     's_CBL3CIPK3_cyt_c',
#     's_CBL3CIPK9_cyt_c',
#     's_CBL3CIPK23_cyt_c',
#     's_CBL3CIPK26_cyt_c',
#     's_TIC56_cyt_p',
#     's_DXR_cyt_p',
#     's_PIF3TOC1SP6Acomplex_cyt_c',
#     's_ISPH_cyt_p',
#     's_BN2_cyt_p',
#     's_Photosynthesis_cyt_pr',
#     's_CBL4Ca2_cyt_ca',
#     's_CBL4CIPK24_cyt_ca',
#     's_PHYBPIF3_nuc_c',
#     's_SnRK210_cyt_pa',
#     's_WRKY50TGA2_cyt_ca',
#     's_bZIP61_cyt_p',
#     's_ICS1_cyt_p',
#     's_MIZ1CPK4_cyt_ca',
#     's_MIZ1CPK6_cyt_ca',
#     's_MIZ1_cyt_p',
#     's_CPK12GRF8_cyt_ca',
#     's_CPK12_nuc_pa'
# ]

# %%
inputs = [node for node in g.nodes if g.in_degree(node) == 0 and node.startswith ('s_')]
inputs
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     's_VPg_cyt_p',
#     's_LHB1B1_cyt_p',
#     's_PSB33_cyt_p',
#     's_HCPro_cyt_p',
#     's_OSCA1_cyt_p',
#     's_Drought_cyt_ab',
#     's_EDF2_cyt_p',
#     's_CML_cyt_pa',
#     's_BZO1_cyt_pa',
#     's_SERPIN1_cyt_p',
#     's_clpP1_cyt_p',
#     's_FQR1_cyt_p',
#     's_PR3like_cyt_p',
#     's_TDX_cyt_p',
#     's_P3_cyt_p',
#     's_RBC_cyt_pa',
#     's_OBE1_cyt_p',
#     's_RH8_cyt_p',
#     's_RPS12C_cyt_p',
#     's_MTI2011_cyt_p',
#     's_ETR_er_p',
#     's_SAMS_er_pa',
#     's_SAHH_er_pa',
#     's_HSP90_cyt_p',
#     's_RAR1_cyt_p',
#     's_SGT1_cyt_p',
#     's_PR5_cyt_p',
#     's_AGO1_cyt_pa',
#     's_SAGs_nuc_p',
#     's_CI_cyt_p',
#     's_CPIP_cyt_pa',
#     's_CP_cyt_p',
#     's_ATG13A_cyt_pa',
#     's_ATPB_cyt_p',
#     's_NDR1_cyt_p',
#     's_MIND1_cyt_p',
#     's_PAA2_cyt_p',
#     's_PBB2_cyt_p',
#     's_TGA256_nuc_pa',
#     's_D14_cyt_p',
#     's_Rx_cyt_p',
#     's_RANGAP_cyt_pa',
#     's_GPAphid2_cyt_p',
#     's_PBE1_cyt_p',
#     's_WRKY17_cyt_p',
#     's_WRKY11_cyt_p',
#     's_GAPC2_cyt_p',
#     's_AT3G17020_cyt_p',
#     's_HEN1_cyt_pa',
#     's_PUB15_cyt_pa',
#     's_EPS1_cyt_pa',
#     's_FLS2_cyt_p',
#     's_MKS1_cyt_p',
#     's_PSAK_cyt_p',
#     's_GID_nuc_pa',
#     's_SLR1_cyt_pa',
#     's_DELLA_nuc_p',
#     's_ESP_cyt_p',
#     's_WRKY30_cyt_p',
#     's_WRKY57_nuc_pa',
#     's_AUXIAA_nuc_pa',
#     's_SCL14_nuc_p',
#     's_MYC2_nuc_pa',
#     's_LSD1_cyt_p',
#     's_ACX_per_p',
#     's_MAX2_cyt_pa',
#     's_tRNAadenine_cyt_m',
#     's_IPT29_cyt_pa',
#     's_ADK_cyt_pa',
#     's_UGT_cyt_pa',
#     's_TIP12_cyt_p',
#     's_SAMS_cyt_pa',
#     's_NIMIN_nuc_p',
#     's_ACS_cyt_pa',
#     's_ACO_cyt_pa',
#     's_Thr_cyt_m',
#     's_OMR1_cyt_pa',
#     's_AOS_chl_pa',
#     's_AOC_chl_pa',
#     's_potyvirus_cyt_pa',
#     's_TNL_cyt_pa',
#     's_CUL_cyt_p',
#     's_RBX_cyt_p',
#     's_ASK_cyt_pa',
#     's_OPCL1_per_pa',
#     's_MFP_per_pa',
#     's_KAT_per_pa',
#     's_ACH_per_pa',
#     's_JMT_cyt_pa',
#     's_JAR_cyt_pa',
#     's_CYP94_cyt_pa',
#     's_MES_cyt_pa',
#     's_OBE2_cyt_p',
#     's_Chor_chl_m',
#     's_CM_chl_pa',
#     's_PAL_chl_pa',
#     's_AAO_chl_pa',
#     's_BA2H_chl_pa',
#     's_SAMC_cyt_pa',
#     's_ATG1A_cyt_pa',
#     's_SOD_mit_pa',
#     's_O2_x_m',
#     's_e_chl_m',
#     's_GeranylgeranylPP_cyt_m',
#     's_CPS_cyt_pa',
#     's_KS_cyt_pa',
#     's_KO_cyt_pa',
#     's_KAO12_cyt_pa',
#     's_GA3ox_cyt_pa',
#     's_C19GA2ox_cyt_pa',
#     's_GAMT12_cyt_pa',
#     's_D27_cyt_pa',
#     's_MAX1_cyt_pa',
#     's_HMBDP_cyt_m',
#     's_ISPH_cyt_pa',
#     's_IPT1345678_cyt_pa',
#     's_phospholipids_chl_m',
#     's_DAD1_chl_pa',
#     's_Growth_cyt_pr',
#     's_JASSY_cyt_pa',
#     's_CYP735A1A2_cyt_pa',
#     's_miR168_cyt_pa',
#     's_UPL5_cyt_pa',
#     's_ROS_cyt_m',
#     's_AOX_cyt_pa',
#     's_CAMTA3_nuc_pa',
#     's_SR1IP1_nuc_pa',
#     's_GPX_cyt_pa',
#     's_vsiRNA34327_cyt_nc',
#     's_vsiRNA12986_cyt_nc',
#     's_CO2deficiency_chl_pr',
#     's_Waterlogging_cyt_ab',
#     's_phasiRNA931_cyt_nc',
#     's_RISCvsiRNA_cyt_pr',
#     's_miR159AB_cyt_nc',
#     's_miR319a3p_cyt_nc',
#     's_D53_cyt_pa',
#     's_Cu2_cyt_m',
#     's_HMA_er_pa',
#     's_CTS_chl_pa',
#     's_JAT2_per_pa',
#     's_MOS_nuc_pa',
#     's_RTE1_ga_pa',
#     's_TRXH_cyt_p',
#     's_VISO_cyt_pa',
#     's_ERF6_nuc_p',
#     's_Heat_cyt_ab',
#     's_AAO_cyt_pa',
#     's_ERF5_cyt_p',
#     's_ABA2_cyt_pa',
#     's_ERF104_cyt_p',
#     's_NCED_cyt_pa',
#     's_ERF105_cyt_p',
#     's_VDE1_cyt_pa',
#     's_GRX480_nuc_p',
#     's_WAK1_cyt_p',
#     's_OG_cyt_m',
#     's_TYRAAT12_cyt_pa',
#     's_CRT_cyt_p',
#     's_ZEP_cyt_pa',
#     's_CML_cyt_p',
#     's_RBOH_ap_p',
#     's_BETAOHASE_cyt_pa',
#     's_LCY1_cyt_pa',
#     's_WRKY8_nuc_p',
#     's_WRKY28_nuc_p',
#     's_WRKY48_nuc_p',
#     's_CBP60G_nuc_p',
#     's_CAMTA3_cyt_p',
#     's_ZDS1_cyt_pa',
#     's_AHP_cyt_p',
#     's_WDbHLHMYB_nuc_ca',
#     's_EIN5_nuc_pa',
#     's_CTR_cyt_pa',
#     's_MIR390_cyt_nc',
#     's_PDS_cyt_pa',
#     's_4CL_per_pa',
#     's_ERFORA59_nuc_pa',
#     's_JAM_nuc_pa',
#     's_miR167e3p_cyt_nc',
#     's_miR6022_cyt_nc',
#     's_WRKY618_nuc_pa',
#     's_CCD_cyt_pa',
#     's_LOG_cyt_pa',
#     's_CKX_cyt_pa',
#     's_APT_cyt_pa',
#     's_PIF34_cyt_pa',
#     's_BACoA_per_m',
#     's_DHNAT2_per_pa',
#     's_ETP_cyt_p',
#     's_TUBA2_cyt_p',
#     's_ERF1_nuc_pa',
#     's_EIN2_cyt_pa',
#     's_CHY1_per_pa',
#     's_REM12_cyt_p',
#     's_CDF1_nuc_pa',
#     's_SES_nuc_mi',
#     's_EIF4E1_cyt_p',
#     's_ERF11_nuc_pa',
#     's_EIJP1_chl_pa',
#     's_TOR_cyt_pa',
#     's_GH3_cyt_pa',
#     's_LST8_cyt_pa',
#     's_trichousbacteria_cyt_f',
#     's_RAPTOR2_cyt_pa',
#     's_NPR3_nuc_pa',
#     's_NPR4_nuc_pa',
#     's_MKK1_cyt_p',
#     's_MKD1_cyt_pa',
#     's_Trp_cyt_m',
#     's_iaaM_cyt_pa',
#     's_SARD1_nuc_pa',
#     's_Salkylthiohydroximate_cyt_m',
#     's_SUR1_cyt_pa',
#     's_Ca2_x_m',
#     's_MVA_cyt_m',
#     's_TCP8_nuc_pa',
#     's_IAAAla_cyt_m',
#     's_IAR_cyt_pa',
#     's_TAA1_cyt_pa',
#     's_BRI1_cyt_p',
#     's_Brassinolide_cyt_m',
#     's_CYP79B2_cyt_pa',
#     's_CYP83B1_cyt_pa',
#     's_IAN_cyt_m',
#     's_NIT1_cyt_pa',
#     's_AMI1_cyt_pa',
#     's_MVK_cyt_p',
#     's_IAALeu_cyt_m',
#     's_ILR1_cyt_pa',
#     's_SIK1_cyt_pa',
#     's_MeIAA_cyt_m',
#     's_IAMT1_cyt_pa',
#     's_LECRK19_cyt_p',
#     's_eATP_x_m',
#     's_IAA_chl_m',
#     's_UGT84B1_chl_pa',
#     's_Phe_cyt_m',
#     's_LDopa_cyt_m',
#     's_ELI5_cyt_pa',
#     's_TIR1_nuc_p',
#     's_ARF_nuc_pa',
#     's_PP2C_cyt_pa',
#     's_GBF4_nuc_p',
#     's_BRAHMA_cyt_pa',
#     's_GER3_cyt_p',
#     's_bZIP21_nuc_p',
#     's_Stomatalclosure_cyt_pr',
#     's_OSCA13_cyt_p',
#     's_CAU1_cyt_pa',
#     's_BSK_cyt_p',
#     's_BSU1_cyt_p',
#     's_BZR2_nuc_p',
#     's_WRKY618_cyt_p',
#     's_CDK_nuc_p',
#     's_CA_cyt_m',
#     's_CTS_per_pa',
#     's_PIF34_nuc_pa',
#     's_NPR1_nuc_p',
#     's_TCP81415_nuc_pa',
#     's_PEP_cyt_p',
#     's_Prep_cyt_m',
#     's_PA_cyt_pa',
#     's_Larogenate_chl_m',
#     's_ADT_chl_pa',
#     's_CYP73A5_cyt_pa',
#     's_potyvirus_cyt_f',
#     's_PAB2_cyt_p',
#     's_DCL24_cyt_pa',
#     's_SAMe_cyt_mr',
#     's_AGO1_cyt_mr',
#     's_mevsiRNA_cyt_pa',
#     's_PAB4_cyt_p',
#     's_SAHH_cyt_pa',
#     's_MS_cyt_pa',
#     's_PAB8_cyt_p',
#     's_phospholipids_cyt_m',
#     's_PLDALPHA1_cyt_pa',
#     's_GSNO_cyt_pa',
#     's_Glu_cyt_m',
#     's_PBS3_cyt_pa',
#     's_6K2_cyt_p',
#     's_AGO7_cyt_p',
#     's_MIR390_cyt_mi',
#     's_PORB_cyt_p',
#     's_PORA_cyt_p',
#     's_FBA8_cyt_p',
#     's_GSTF9_cyt_p',
#     's_HUP54_cyt_p',
#     's_EDS5_chl_pa',
#     's_VDAC2_cyt_p',
#     's_PSBR_cyt_p',
#     's_P1_cyt_p',
#     's_MSL_cyt_p',
#     's_NIaPro_cyt_p',
#     's_NIb_cyt_p',
#     's_BAS1_cyt_p',
#     's_RBC_cyt_p',
#     's_PSBP1_cyt_p',
#     's_RCA_cyt_p',
#     's_MED37E_cyt_p',
#     's_IPP2_cyt_p',
#     's_ABCF1_cyt_p',
#     's_CLPR3_cyt_p',
#     's_MES10_cyt_pa',
#     's_ORA59_nuc_g',
#     's_psbB_cyt_p',
#     's_BCCP1_cyt_p',
#     's_GRF6_cyt_p',
#     's_CAC2_cyt_p',
#     's_MPPBETA_cyt_p',
#     's_ATPC1_cyt_p',
#     's_MYC3_cyt_pa',
#     's_MYC4_cyt_pa',
#     's_CNGC2_cyt_p',
#     's_GI_nuc_p',
#     's_GI_cyt_p',
#     's_PROC1_cyt_pa',
#     's_MYB2_cyt_pa',
#     's_ATAF1_cyt_pa',
#     's_PTP1a_cyt_p',
#     's_MKK1_cyt_pa_1',
#     's_EIN3NPR1_nuc_ca',
#     's_EIN3like_cyt_p',
#     's_MPK4_cyt_p',
#     's_ERF11_cyt_pa',
#     's_InsP4_cyt_m',
#     's_ITPK1_cyt_pa',
#     's_IPK1_cyt_pa',
#     's_RAP26_cyt_pa',
#     's_CDK_nuc_pa',
#     's_VIH1_cyt_pa',
#     's_CDG1_cyt_pa',
#     's_HSP70_cyt_p',
#     's_COI1_cyt_p',
#     's_HSP70HSP90SGT1_cyt_ca',
#     's_TIR1_cyt_p',
#     's_SGT1_cyt_pa',
#     's_NAC92_cyt_p',
#     's_CML12_cyt_p',
#     's_PID_cyt_pa',
#     's_PBP1_cyt_p',
#     's_KRP1_cyt_p',
#     's_ICR1_cyt_pa',
#     's_BRI1_cyt_pa',
#     's_miR398b_cyt_mi',
#     's_HSFA1b_cyt_p',
#     's_NGA1_cyt_pa',
#     's_ABAGE_cyt_m',
#     's_BGLU18_er_pa',
#     's_BGLU18_cyt_p',
#     's_CYP707A3_cyt_pa',
#     's_PAR_cyt_pa',
#     's_DAO1_cyt_pa',
#     's_DREB1B_cyt_pa',
#     's_SARD1_cyt_pa',
#     's_CBP60G_cyt_pa',
#     's_ROP9_cyt_p',
#     's_RBOHB_cyt_p',
#     's_FKBP42_cyt_p',
#     's_CAM1_cyt_p',
#     's_MPK7_cyt_p',
#     's_ELF3_cyt_pa',
#     's_PHOR1_cyt_pa',
#     's_CIPK1_cyt_p',
#     's_CBL1_cyt_p',
#     's_CBL9_cyt_p',
#     's_FKBP62_cyt_p',
#     's_CIPK23_cyt_p',
#     's_IDD14_nuc_p',
#     's_AREBABF_nuc_p',
#     's_IDD14_nucl_p',
#     's_ERFVII_cyt_p',
#     's_HSFA1d_cyt_p',
#     's_PHYA_cyt_p',
#     's_redlight_cyt_ab',
#     's_ABI4_cyt_p',
#     's_HY5_cyt_p',
#     's_ABI4_cyt_pa',
#     's_ABI4RGL2_cyt_ca',
#     's_ABI5HY5_cyt_ca',
#     's_HSF_cyt_p',
#     's_ORA59_cyt_pa',
#     's_CBL2_cyt_p',
#     's_CBL3_cyt_p',
#     's_DREB1D_cyt_pa',
#     's_SPCH_cyt_pa',
#     's_CDF1_cyt_pa',
#     's_JAZ_cyt_pa',
#     's_JAM_cyt_pa',
#     's_CIPK3_cyt_p',
#     's_CIPK9_cyt_p',
#     's_MYC2_cyt_pa',
#     's_CIPK26_cyt_p',
#     's_cholesterol_cyt_m',
#     's_bHLH93_cyt_pa',
#     's_PIF1_cyt_pa',
#     's_PIF34_cyt_p_1',
#     's_SP6A_cyt_p',
#     's_CLAMT_cyt_pa',
#     's_miR168_cyt_mi',
#     's_BN2_cyt_pa',
#     's_MKK2_cyt_p',
#     's_Photosynthesis_chl_pra',
#     's_Photosynthesis_cyt_pra',
#     's_CO2deficiency_cyt_pra',
#     's_CBL4_cyt_pa',
#     's_CIPK24_cyt_pa',
#     's_CPK27_cyt_pa',
#     's_CPK3_cyt_pa',
#     's_PHYB_nuc_pa',
#     's_SnRK210_cyt_p',
#     's_HOP3_cyt_pa',
#     's_CAX1_cyt_p',
#     's_CBL2CIPK3_cyt_ca',
#     's_CBL2CIPK9_cyt_ca',
#     's_CBL2CIPK26_cyt_ca',
#     's_CBL3CIPK3_cyt_ca',
#     's_CBL3CIPK9_cyt_ca',
#     's_CBL3CIPK26_cyt_ca',
#     's_CAX3_cyt_p',
#     's_NRG11_cyt_p',
#     's_WRKY50_cyt_pa',
#     's_TGA256_cyt_pa',
#     's_bZIP61_cyt_pa',
#     's_NPR3L_cyt_pa',
#     's_MIZ1_cyt_pa',
#     's_GRF8_cyt_pa',
#     's_CPK12_cyt_pa'
# ]
